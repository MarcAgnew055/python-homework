# %%
import os
import csv

mypath = '/Users/marcagnew/GitHub/python-homework/PyBank' 

budgetCSV = os.path.join(mypath, 'budget_data.csv')

# Improved Reading of CSV file
with open(budgetCSV, 'r') as csvfile:
  
    csvreader = csv.reader(csvfile, delimiter=',')

    header = next(csvreader)

    # Variables
    rows = 0
    total = 0
    Profit = 0
    Loss = 0
    row_profit = 0
    row_loss = 0
    Max = 0
    Min = 0

    # Initialize variables for calculations
    Total_PL_list = []
    Month_change = 0
    PL_change_list = []
    Total_months_list = []
    current_PL = 0
    last_PL = 0

    # Loop 

    for row in csvreader:
        rows += 1

        total = total + int(row[1])

        if (int(row[1]) > 0):
            Profit += Profit + int(row[1])
            row_profit += 1
        else:
            Loss += Loss + int(row[1])
            row_loss += 1

        # Average in "Profit/Losses" 
        Total_months_list.append(row[0])
        Total_PL_list.append(int(row[1]))

            # Greatest increase and decrease in profits 

        if (int(row[1]) > Max):
            Max = int(row[1])
            Month_max = row[0]
        elif (int(row[1]) < Min):
            Min = int(row[1])
            Month_min = row[0]

    for i in range(len(Total_PL_list) - 1):
        PL_change_list.append(Total_PL_list[i + 1] - Total_PL_list[i])

    Average_change = (sum(PL_change_list)) / (len(PL_change_list))


# Print Statements 
print("Financial Analysis")
print("-----------------------\n")
print(f"Total Months: {str(rows)} \n")
print(f"Total: ${str(total)}\n")
print(f"Average Change: ${str('%.2f' % Average_change)}\n")
print(f"Greatest Increase in Profits: {Month_max} (${str(Max)})\n")
print(f"Greatest Decrease in Profits: {Month_min} (${str(Min)})\n")

# Export text file 
results_file = ('/Users/marcagnew/GitHub/python-homework/PyBank/Results.txt')

# Output file 
with open(results_file, 'w') as file:
    file.write("Financial Analysis")
    file.write("-----------------------\n")
    file.write(f"Total Months: {str(rows)} \n")
    file.write(f"Total: ${str(total)}\n")
    file.write(f"Average Change: ${str('%.2f' % Average_change)}\n")
    file.write(f"Greatest Increase in Profits: {Month_max} (${str(Max)})\n")
    file.write(f"Greatest Decrease in Profits: {Month_min} (${str(Min)})\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jk/xsphk5ys6z9_3mpy5dqxn43r0000gn/T/ipykernel_12341/4000723898.py in <module>
#       3 mypath = '/Users/marcagnew/GitHub/python-homework/PyBank'
#       4
# ----> 5 budgetCSV = os.path.join(mypath, 'budget_data.csv')
#       6
#       7 # Improved Reading of CSV file
#
# NameError: name 'os' is not defined
